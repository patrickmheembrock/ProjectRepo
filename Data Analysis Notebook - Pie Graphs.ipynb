# %%
## Project: 2014 Heart Disease Mortality of 500 Random Counties, based on the Concentration of McDonald's Restaurants
## Further Considerations by Gender, Race/Ethnicity, and Income Level

## Data Analysis Notebook

# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#Importing Cleaned CDC Data
cdc_pd = pd.read_csv("Final_Clean_CDC_Data.csv")
cdc_pd.head()
# Out:
#   State              County  Deaths per 100,000   Gender Race/Ethnicity  \
# 0    AK  Aleutians East, AK               105.3  Overall        Overall
# 1    AK  Aleutians West, AK               211.9  Overall        Overall
# 2    AK       Anchorage, AK               257.9  Overall        Overall
# 3    AK          Bethel, AK               351.6  Overall        Overall
# 4    AK          Denali, AK               305.5  Overall        Overall
#
#    Geographical Coordinates
# 0  (55.440626, -161.962562)
# 1  (52.995403, -170.251538)
# 2  (61.159049, -149.103905)
# 3  (60.924483, -159.749655)
# 4  (63.678399, -149.962076)

# %%
# Importing the Dataframe of 500 Random Counties and their number of McDonalds
mcd_pd = pd.read_csv("Mcdonalds_per_County.csv")
mcd_pd.head()
# Out:
#              County  Number of Mcdonalds
# 0    Ada County, ID                   30
# 1  Adams County, CO                   50
# 2  Adams County, IL                    4
# 3  Adams County, MS                    3
# 4  Adams County, ND                    1

# %%
# Merging the two dataframes so that we have mortality information for only 500 counties
sample_counties = pd.merge(cdc_pd, mcd_pd, on="County")
sample_counties.sort_values("County")
# Out:
#      State             County  Deaths per 100,000   Gender  \
# 1096    ID     Ada County, ID               226.1   Female
# 1098    ID     Ada County, ID               181.3  Overall
# 1097    ID     Ada County, ID               217.3  Overall
# 1101    ID     Ada County, ID               142.3  Overall
# 1095    ID     Ada County, ID               347.6     Male
# 1094    ID     Ada County, ID               278.2  Overall
# 1093    ID     Ada County, ID               221.9   Female
# 1092    ID     Ada County, ID               344.3     Male
# 1099    ID     Ada County, ID               251.9     Male
# 1091    ID     Ada County, ID               274.5  Overall
# 1103    ID     Ada County, ID               136.8   Female
# 1102    ID     Ada County, ID               151.8     Male
# 1100    ID     Ada County, ID               117.4   Female
# 351     CO   Adams County, CO               464.6     Male
# 335     CO   Adams County, CO               262.8  Overall
# 336     CO   Adams County, CO               322.7     Male
# 337     CO   Adams County, CO               209.2   Female
# 338     CO   Adams County, CO               282.7  Overall
# 339     CO   Adams County, CO               353.7     Male
# 342     CO   Adams County, CO               339.9     Male
# 343     CO   Adams County, CO               294.0   Female
# 344     CO   Adams County, CO               194.0  Overall
# 345     CO   Adams County, CO               224.1     Male
# 346     CO   Adams County, CO               168.3   Female
# 347     CO   Adams County, CO               146.5  Overall
# 348     CO   Adams County, CO               220.6     Male
# 349     CO   Adams County, CO               114.6   Female
# 350     CO   Adams County, CO               317.1  Overall
# 340     CO   Adams County, CO               217.2   Female
# 341     CO   Adams County, CO               337.9  Overall
# ...    ...                ...                 ...      ...
# 4720    VA   Wythe County, VA               523.4     Male
# 4721    VA   Wythe County, VA               358.8   Female
# 4722    VA   Wythe County, VA               239.4  Overall
# 4716    VA   Wythe County, VA               443.9  Overall
# 4718    VA   Wythe County, VA               358.4   Female
# 326     CA    Yuba County, CA               272.9   Female
# 327     CA    Yuba County, CA               202.5  Overall
# 324     CA    Yuba County, CA               344.0  Overall
# 334     CA    Yuba County, CA               283.5     Male
# 325     CA    Yuba County, CA               381.7     Male
# 328     CA    Yuba County, CA               301.5     Male
# 333     CA    Yuba County, CA               330.2  Overall
# 332     CA    Yuba County, CA               133.2   Female
# 4461                             Overall   (27.000684, -99.174828)
# 4463                               White   (27.000684, -99.174828)
# 4460                             Overall   (27.000684, -99.174828)
# 4459                             Overall   (27.000684, -99.174828)
# 4466                            Hispanic   (27.000684, -99.174828)
# 4465                            Hispanic   (27.000684, -99.174828)
# 4462                               White   (27.000684, -99.174828)
# 4464                            Hispanic   (27.000684, -99.174828)
#
#       Number of Mcdonalds
# 1096                   30
# 1098                   30
# 1097                   30
# 1101                   30
# 1095                   30
# 1094                   30
# 1093                   30
# 1092                   30
# 1099                   30
# 1091                   30
# 1103                   30
# 1102                   30
# 1100                   30
# 351                    50
# 335                    50
# 336                    50
# 337                    50
# 338                    50
# 339                    50
# 342                    50
# 343                    50
# 344                    50
# 345                    50
# 346                    50
# 347                    50
# 348                    50
# 349                    50
# 350                    50
# 340                    50
# 341                    50
# ...                   ...
# 4720                   15
# 4721                   15
# 4722                   15
# 4716                   15
# 4718                   15
# 326                    50
# 327                    50
# 324                    50
# 334                    50
# 325                    50
# 328                    50
# 333                    50
# 332                    50
# 331                    50
# 330                    50
# 329                    50
# 323                    50
# 322                    50
# 321                    50
# 320                    50
# 318                    50
# 319                    50
# 4461                   16
# 4463                   16
# 4460                   16
# 4459                   16
# 4466                   16
# 4465                   16
# 4462                   16
# 4464                   16
#
# [4986 rows x 7 columns]

# %%
#Pulling AVERAGE Mortality Rates by Gender to Build Pie Chart Visualizations
genders = ["Male", "Female"]
gender_mort = []

for gender in genders:
        mort = sample_counties.groupby(["Gender"]).get_group((gender))
        tot_mort = mort[(mort["Gender"] == gender) &  (mort["Race/Ethnicity"] == "Overall")]
        tot_mort = tot_mort["Deaths per 100,000"].mean()
        gender_mort.append(tot_mort)

# %%
# The colors of each section of the pie chart
colors = ["lightskyblue", "lightcoral"]

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(gender_mort, labels=genders, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2014 Average Heart Disease Mortality by Gender")

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Save Figure
plt.savefig("Pie_Mortality_by_Gender_Average.png")

# %%
#Pulling AVERAGE Mortality Rates by Race to Build Pie Chart Visualizations
races = ["American Indian and Alaskan Native", "Asian and Pacific Islander", "Black", "Hispanic", "White"]
race_mort = []

for race in races:
        mort = sample_counties.groupby(["Race/Ethnicity"]).get_group((race))
        tot_mort = mort[(mort["Gender"] == "Overall") &  (mort["Race/Ethnicity"] == race)]
        tot_mort = tot_mort["Deaths per 100,000"].mean()
        race_mort.append(tot_mort)

# %%
colors = ["yellow", "orange", "blue", "lightcoral", "lightskyblue"]

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(race_mort, labels=races, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2014 Average Heart Disease Mortality by Race")

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Save Figure
plt.savefig("Pie_Mortality_by_Race_Average.png")

# %%
#Pulling TOTAL Mortality Rates by Race to Build Pie Chart Visualizations
races = ["American Indian and Alaskan Native", "Asian and Pacific Islander", "Black", "Hispanic", "White"]
race_mort = []

for race in races:
        mort = sample_counties.groupby(["Race/Ethnicity"]).get_group((race))
        tot_mort = mort[(mort["Gender"] == "Overall") &  (mort["Race/Ethnicity"] == race)]
        tot_mort = tot_mort["Deaths per 100,000"].sum()
        race_mort.append(tot_mort)

# %%
colors = ["yellow", "orange", "blue", "lightcoral", "lightskyblue"]

# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(race_mort, labels=races, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2014 Total Heart Disease Mortality by Race")

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Save Figure
plt.savefig("Pie_Mortality_by_Race_Total.png")

# %%
#Importing Cleaned IRS Data
irs_pd = pd.read_csv("Final_Clean_IRS_Data.csv")

irs_pd.head()
# Out:
#                County Adjusted Gross Income  Number of Returns  \
# 0  Autauga County, AL              Under $1              210.0
# 1  Autauga County, AL            1 - $9,999             3350.0
# 2  Autauga County, AL      10,000 - $24,999             5620.0
# 3  Autauga County, AL      25,000 - $49,999             5410.0
# 4  Autauga County, AL      50,000 - $74,999             3420.0
#
#    Total Salaries & Wages
# 0                  1403.0
# 1                 14437.0
# 2                 77486.0
# 3                159789.0
# 4                163864.0

# %%
# Pulling Overall Mortality for Scatter Plot
overall_mort = sample_counties.groupby(["Gender"]).get_group(("Overall"))
overall_mort = overall_mort[(overall_mort["Gender"] == "Overall") &  (overall_mort["Race/Ethnicity"] == "Overall")]
tot_mort = overall_mort["Deaths per 100,000"]
tot_mcds = overall_mort["Number of Mcdonalds"]

# Building the Scatter Plot
plt.scatter(tot_mcds, tot_mort, marker="o", facecolors="gold", edgecolors="red", alpha=0.75)

# Labeling the Scatter Plot
plt.xlabel("Total Number of McDonalds (Per County)")
plt.ylabel("Mortality Rate (per 100,000)")
plt.grid()
plt.title("County Heart Disease Mortality Rate per Number of McDonalds (2014)")

# Save Figure
plt.savefig("Scatter_Mortality_by_County.png")

# %%
stats.ttest_ind(tot_mcds, tot_mort, equal_var=False)
# Out:
# Ttest_indResult(statistic=-89.83173364283014, pvalue=0.0)

# %%
# Creating a Bar Graph showing the AVERAGE Mortality by Race, Further Broken Down by Gender
races = ["American Indian and Alaskan Native", "Asian and Pacific Islander", "Black", "Hispanic", "White"]
genders = ["Male", "Female"]

barmale = []
barfemale = []

for gender in genders:
    for race in races:
        mort = sample_counties.groupby(["Race/Ethnicity"]).get_group((race))
        tot_mort = mort[(mort["Gender"] == gender) &  (mort["Race/Ethnicity"] == race)]
        tot_mort = tot_mort["Deaths per 100,000"].mean()
        if len(barmale) >= 5:
            barfemale.append(tot_mort)
        else:
            barmale.append(tot_mort)

plt.barh(races, barmale, color="blue", edgecolor="white")
plt.barh(races, barfemale, color="red", edgecolor="white")
plt.title("Comparing Average Mortality by Gender (broken down by race)")
plt.xlabel("Average Deaths (per 100,000)")

# Save Figure
plt.savefig("Bar_Avg_Mortality_by_Race-Gender.png")

# %%
# Creating a Bar Graph showing the TOTAL Mortality by Race, Further Broken Down by Gender
races = ["American Indian and Alaskan Native", "Asian and Pacific Islander", "Black", "Hispanic", "White"]
genders = ["Male", "Female"]

barmale = []
barfemale = []

for gender in genders:
    for race in races:
        mort = sample_counties.groupby(["Race/Ethnicity"]).get_group((race))
        tot_mort = mort[(mort["Gender"] == gender) &  (mort["Race/Ethnicity"] == race)]
        tot_mort = tot_mort["Deaths per 100,000"].sum()
        if len(barmale) >= 5:
            barfemale.append(tot_mort)
        else:
            barmale.append(tot_mort)

plt.barh(races, barmale, color="blue", edgecolor="white")
plt.barh(races, barfemale, color="red", edgecolor="white")
plt.title("Comparing Total Mortality by Gender (broken down by race)")
plt.xlabel("Total Deaths")

# Save Figure
plt.savefig("Bar_Tot_Mortality_by_Race-Gender.png")
